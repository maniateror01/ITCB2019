# %% [markdown]
# <a href="https://colab.research.google.com/github/maniateror01/ITCB2019/blob/master/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
    https://download1493.mediafire.com/axs9v3oao4wg/ybrr9x1mx7ewj3d/daun_nangka_and_daun_belimbing_filtered.zip \
    -O /tmp/daun_herbal.zip
# Out:
# --2021-11-16 05:23:24--  https://download1493.mediafire.com/axs9v3oao4wg/ybrr9x1mx7ewj3d/daun_nangka_and_daun_belimbing_filtered.zip
# Resolving download1493.mediafire.com (download1493.mediafire.com)... 205.196.123.181
# Connecting to download1493.mediafire.com (download1493.mediafire.com)|205.196.123.181|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27697930 (26M) [application/zip]
# Saving to: ‘/tmp/daun_herbal.zip’
#
# /tmp/daun_herbal.zi 100%[===================>]  26.41M  11.9MB/s    in 2.2s
#
# 2021-11-16 05:23:27 (11.9 MB/s) - ‘/tmp/daun_herbal.zip’ saved [27697930/27697930]

# %%
import os
import zipfile

local_zip = '/tmp/daun_herbal.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/daun_nangka_and_daun_belimbing_filtered/daun_herbal'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_daun_belimbing_dir = os.path.join(train_dir, 'daun_belimbing')
train_daun_nangka_dir = os.path.join(train_dir, 'daun_nangka')

validation_daun_belimbing_dir = os.path.join(validation_dir, 'daun_belimbing')
validation_daun_nangka_dir = os.path.join(validation_dir, 'daun_nangka')

# %%
print(os.listdir(train_daun_belimbing_dir)[:10])
print(os.listdir(train_daun_nangka_dir)[:10])
# Out:
# ['068.jpg', '087.jpg', '057.jpg', '051.jpg', '074.jpg', '081.jpg', '056.jpg', '075.jpg', '060.jpg', '065.jpg']
# ['021.jpg', '011.jpg', '044.jpg', '046.jpg', '003.jpg', '023.jpg', '012.jpg', '014.jpg', '028.jpg', '039.jpg']

# %%
# Cek jumlah data train dan data validation
print('total training daun_belimbing images:', len(os.listdir(train_daun_belimbing_dir)))
print('total training daun_nangka images:', len(os.listdir(train_daun_nangka_dir)))
print('total validation daun_belimbing images:', len(os.listdir(validation_daun_belimbing_dir)))
print('total validation daun_nangka images:', len(os.listdir(validation_daun_nangka_dir)))
# Out:
# total training daun_belimbing images: 50
# total training daun_nangka images: 50
# total validation daun_belimbing images: 50
# total validation daun_nangka images: 50

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_cat_pix = [os.path.join(train_daun_belimbing_dir, fname) 
                for fname in os.listdir(train_daun_belimbing_dir)[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_daun_nangka_dir, fname) 
                for fname in os.listdir(train_daun_nangka_dir)[pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
# Out:
# Train Data =  (100, 150, 150, 3)
# Train Label =  (100,)
# Validation Data =  (100, 150, 150, 3)
# Validation Label =  (100,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [233 233 233]
# Data setelah di-normalisasi  [0.9137255 0.9137255 0.9137255]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Buat model dengan 1 input layer, 1 hidden layer, dan 1 output layer
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) # ubah dari matriks 150x150x3 menjadi vektor
x = layers.Dense(128, activation='relu')(x) # hidden layer 1 dengan 128 neuron
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)

# Definisikan modelnya
model = Model(img_input, output)

# %%
# Tampilkan model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 128)               8640128
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,640,257
# Trainable params: 8,640,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 82ms/step - loss: 40.9720 - acc: 0.5000 - val_loss: 42.4944 - val_acc: 0.5000
# Epoch 2/50
# 5/5 [==============================] - 0s 48ms/step - loss: 15.2189 - acc: 0.5400 - val_loss: 7.6212 - val_acc: 0.5000
# Epoch 3/50
# 5/5 [==============================] - 0s 46ms/step - loss: 6.3458 - acc: 0.5800 - val_loss: 0.7166 - val_acc: 0.6300
# Epoch 4/50
# 5/5 [==============================] - 0s 47ms/step - loss: 1.2114 - acc: 0.6800 - val_loss: 0.0612 - val_acc: 0.9800
# Epoch 5/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4706 - acc: 0.8900 - val_loss: 0.2293 - val_acc: 0.9400
# Epoch 6/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1180 - acc: 0.9500 - val_loss: 0.1133 - val_acc: 0.9800
# Epoch 7/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1994 - acc: 0.9400 - val_loss: 0.0836 - val_acc: 0.9900
# Epoch 8/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0340 - acc: 0.9900 - val_loss: 0.0107 - val_acc: 0.9900
# Epoch 9/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0805 - acc: 0.9700 - val_loss: 0.0971 - val_acc: 0.9600
# Epoch 10/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0336 - acc: 0.9800 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 50ms/step - loss: 4.2032e-04 - acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9900
# Epoch 12/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0183 - acc: 0.9900 - val_loss: 0.0195 - val_acc: 0.9900
# Epoch 13/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0201 - acc: 0.9900 - val_loss: 0.0113 - val_acc: 0.9900
# Epoch 14/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0083 - acc: 0.9900 - val_loss: 8.6912e-04 - val_acc: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 51ms/step - loss: 8.9584e-04 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0026 - val_acc: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 50ms/step - loss: 8.4096e-04 - acc: 1.0000 - val_loss: 6.2818e-04 - val_acc: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 49ms/step - loss: 5.7390e-04 - acc: 1.0000 - val_loss: 4.1065e-04 - val_acc: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 47ms/step - loss: 3.5215e-04 - acc: 1.0000 - val_loss: 3.7724e-04 - val_acc: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 47ms/step - loss: 3.6693e-04 - acc: 1.0000 - val_loss: 3.8427e-04 - val_acc: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 49ms/step - loss: 4.0754e-04 - acc: 1.0000 - val_loss: 3.9753e-04 - val_acc: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 48ms/step - loss: 4.0591e-04 - acc: 1.0000 - val_loss: 3.9378e-04 - val_acc: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 48ms/step - loss: 3.9161e-04 - acc: 1.0000 - val_loss: 3.7402e-04 - val_acc: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 48ms/step - loss: 3.6141e-04 - acc: 1.0000 - val_loss: 3.5717e-04 - val_acc: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 46ms/step - loss: 3.5745e-04 - acc: 1.0000 - val_loss: 3.3767e-04 - val_acc: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 47ms/step - loss: 3.4011e-04 - acc: 1.0000 - val_loss: 3.2659e-04 - val_acc: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 49ms/step - loss: 3.2390e-04 - acc: 1.0000 - val_loss: 3.2078e-04 - val_acc: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 48ms/step - loss: 3.1726e-04 - acc: 1.0000 - val_loss: 3.1522e-04 - val_acc: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 46ms/step - loss: 3.1451e-04 - acc: 1.0000 - val_loss: 3.0990e-04 - val_acc: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 47ms/step - loss: 3.1122e-04 - acc: 1.0000 - val_loss: 3.0483e-04 - val_acc: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 45ms/step - loss: 3.0599e-04 - acc: 1.0000 - val_loss: 3.0026e-04 - val_acc: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 49ms/step - loss: 3.0028e-04 - acc: 1.0000 - val_loss: 2.9594e-04 - val_acc: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 47ms/step - loss: 2.9558e-04 - acc: 1.0000 - val_loss: 2.9217e-04 - val_acc: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 47ms/step - loss: 2.9406e-04 - acc: 1.0000 - val_loss: 2.8722e-04 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.9076e-04 - acc: 1.0000 - val_loss: 2.8321e-04 - val_acc: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 48ms/step - loss: 2.8423e-04 - acc: 1.0000 - val_loss: 2.7860e-04 - val_acc: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 50ms/step - loss: 2.7704e-04 - acc: 1.0000 - val_loss: 2.7411e-04 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 51ms/step - loss: 2.7260e-04 - acc: 1.0000 - val_loss: 2.7034e-04 - val_acc: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 48ms/step - loss: 2.7082e-04 - acc: 1.0000 - val_loss: 2.6613e-04 - val_acc: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.6550e-04 - acc: 1.0000 - val_loss: 2.6199e-04 - val_acc: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 47ms/step - loss: 2.6085e-04 - acc: 1.0000 - val_loss: 2.5829e-04 - val_acc: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.6160e-04 - acc: 1.0000 - val_loss: 2.5470e-04 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 47ms/step - loss: 2.5637e-04 - acc: 1.0000 - val_loss: 2.5119e-04 - val_acc: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.5425e-04 - acc: 1.0000 - val_loss: 2.4712e-04 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 49ms/step - loss: 2.4646e-04 - acc: 1.0000 - val_loss: 2.4334e-04 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 48ms/step - loss: 2.4770e-04 - acc: 1.0000 - val_loss: 2.4052e-04 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.3994e-04 - acc: 1.0000 - val_loss: 2.3651e-04 - val_acc: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.3719e-04 - acc: 1.0000 - val_loss: 2.3280e-04 - val_acc: 1.0000

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
